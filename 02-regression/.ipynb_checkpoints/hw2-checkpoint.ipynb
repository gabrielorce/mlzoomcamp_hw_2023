# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
#     Markdown

# %%
# On Linux Systems: !wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv

# %%
df = pd.read_csv('housing.csv')
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
fig = plt.figure(figsize=(15,10))
ax = plt.gca()
df.hist(bins=100, ax=ax, layout=(3, 3), column=["longitude", "latitude", "housing_median_age", "total_rooms", "total_bedrooms", 
                                                  "population", "households", "median_income", "median_house_value"])
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Bjorn\AppData\Local\Temp\ipykernel_23636\367074269.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(bins=100, ax=ax, layout=(3, 3), column=["longitude", "latitude", "housing_median_age", "total_rooms", "total_bedrooms",

# %%
sns.distplot(df.median_house_value, bins=50)
# Out:
# C:\Users\Bjorn\AppData\Local\Temp\ipykernel_23636\1909933847.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.median_house_value, bins=50)
# C:\Users\Bjorn\anaconda3\envs\ml-zoomcamp\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# distplot with log1p

sns.distplot(np.log1p(df.median_house_value))
# Out:
# C:\Users\Bjorn\AppData\Local\Temp\ipykernel_23636\4207327258.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log1p(df.median_house_value))
# C:\Users\Bjorn\anaconda3\envs\ml-zoomcamp\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
print (df['ocean_proximity'].unique())
# Out:
# ['NEAR BAY' '<1H OCEAN' 'INLAND' 'NEAR OCEAN' 'ISLAND']

# %%
df.size
# Out:
# 206400

# %%
df=df.loc[(df['ocean_proximity']=='<1H OCEAN') | (df['ocean_proximity']=='INLAND')]
print (df['ocean_proximity'].unique())
# Out:
# ['<1H OCEAN' 'INLAND']

# %%
df.shape
# Out:
# (15687, 10)

# %%
df=df[['latitude',
'longitude',
'housing_median_age',
'total_rooms',
'total_bedrooms',
'population',
'households',
'median_income',
'median_house_value']]
df
# Out:
#        latitude  longitude  housing_median_age  total_rooms  total_bedrooms  \
# 701       37.64    -121.97                32.0       1283.0           194.0
# 830       37.61    -121.99                 9.0       3666.0           711.0
# 859       37.57    -121.97                21.0       4342.0           783.0
# 860       37.58    -121.96                15.0       3575.0           597.0
# 861       37.58    -121.98                20.0       4126.0          1031.0
# ...         ...        ...                 ...          ...             ...
# 20635     39.48    -121.09                25.0       1665.0           374.0
# 20636     39.49    -121.21                18.0        697.0           150.0
# 20637     39.43    -121.22                17.0       2254.0           485.0
# 20638     39.43    -121.32                18.0       1860.0           409.0
# 20639     39.37    -121.24                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# Question 1: Missing Values

# %%
df.isnull().sum()
# Out:
# latitude                0
# longitude               0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        157
# population              0
# households              0
# median_income           0
# median_house_value      0
# dtype: int64

# %% [markdown]
# Question 2: Median of population

# %%
df.population.median()
# Out:
# 1195.0

# %%
# Prepare and split the dataset

n = len(df)

n_val = int(n * 0.2)
n_test = int(n * 0.2)
n_train = n - n_val - n_test
n, n_val, n_test, n_train
# Out:
# (15687, 3137, 3137, 9413)

# %%
# Shuffle the dataset - use seed 42.
idx = np.arange(n)
np.random.seed(42)
np.random.shuffle(idx)

# %%
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train+n_val]]
df_test = df.iloc[idx[n_train+n_val:]]

# %%
df_train.head()
# Out:
#        latitude  longitude  housing_median_age  total_rooms  total_bedrooms  \
# 19963     36.23    -119.14                22.0       2935.0           523.0
# 5929      34.12    -117.79                16.0       2426.0           426.0
# 11377     33.68    -117.97                26.0       3653.0           568.0
# 6443      34.10    -118.03                32.0       2668.0           609.0
# 17546     37.34    -121.87                39.0       2479.0           541.0
#
#        population  households  median_income  median_house_value
# 19963      1927.0       530.0         2.5875             70400.0
# 5929       1319.0       446.0         4.8125            224500.0
# 11377      1930.0       585.0         5.7301            260900.0
# 6443       1512.0       541.0         2.9422            233100.0
# 17546      1990.0       506.0         2.4306            289100.0

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (9413, 3137, 3137)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
df_train.head()
# Out:
#    latitude  longitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     36.23    -119.14                22.0       2935.0           523.0
# 1     34.12    -117.79                16.0       2426.0           426.0
# 2     33.68    -117.97                26.0       3653.0           568.0
# 3     34.10    -118.03                32.0       2668.0           609.0
# 4     37.34    -121.87                39.0       2479.0           541.0
#
#    population  households  median_income  median_house_value
# 0      1927.0       530.0         2.5875             70400.0
# 1      1319.0       446.0         4.8125            224500.0
# 2      1930.0       585.0         5.7301            260900.0
# 3      1512.0       541.0         2.9422            233100.0
# 4      1990.0       506.0         2.4306            289100.0

# %%
#Apply the log transformation to the variable we wish to predict (median_house_value) using the np.log1p() function.
 
y_train = np.log1p(df_train.median_house_value.values)
y_val = np.log1p(df_val.median_house_value.values)
y_test = np.log1p(df_test.median_house_value.values)


# Delete the variable we wish to predict from the training/validation/test datasets

del df_train['median_house_value']
del df_val['median_house_value']
del df_test['median_house_value']

columns_used=list(df_train.columns)

# %%
columns_used
# Out:
# ['latitude',
#  'longitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income']

# %%
def prepare_X(df, fillna_value):
    df_num = df[columns_used]
    df_num = df_num.fillna(fillna_value)
    X = df_num.values
    return X

# %%
def train_linear_regression(X, y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X)
    XTX_inv = np.linalg.inv(XTX)
    w = XTX_inv.dot(X.T).dot(y)
    
    return w[0], w[1:]

# %%
def rmse(y, y_pred):
    error = y_pred - y
    mse = (error ** 2).mean()
    return np.sqrt(mse)

# %% [markdown]
# Question 3: filling missing values with null value versus mean value

# %%
X_null_train = prepare_X(df_train, fillna_value=0)
w_0_null, w_null = train_linear_regression(X_null_train, y_train)

# %%
X_null_val = prepare_X(df_val, fillna_value=0)
y_null_pred_val = w_0_null + X_null_val.dot(w_null)

# %%
np.round(rmse(y_val, y_null_pred_val),2)
# Out:
# 0.34

# %%
mean = df_train.total_bedrooms.mean()

X_mean_train = prepare_X(df_train, fillna_value=mean)
w_0_mean, w_mean = train_linear_regression(X_mean_train, y_train)

# %%
np.round(rmse(y_val, y_mean_pred_val),2)
# Out:
# 0.34

# %% [markdown]
# Question 4:  train a regularized linear regression.

# %%
r_values = [0, 0.000001, 0.0001, 0.001, 0.01, 0.1, 1, 5, 10]

# %%
def train_linear_regression_reg(X, y, r=0.0):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X)
    reg = r * np.eye(XTX.shape[0])
    XTX = XTX + reg

    XTX_inv = np.linalg.inv(XTX)
    w = XTX_inv.dot(X.T).dot(y)
    
    return w[0], w[1:]

# %%
for r in r_values:
    w_0, w = train_linear_regression_reg(X_null_train, y_train, r=r)
    y_null_reg_val = w_0 + X_null_val.dot(w)
    rmse_val = np.round(rmse(y_val, y_null_reg_val),2)
    print(r, w_0, rmse_val)
# Out:
# 0 -9.763249477929213 0.34
# 1e-06 -9.76322883158197 0.34
# 0.0001 -9.761185235939122 0.34
# 0.001 -9.74264624988528 0.34
# 0.01 -9.561056193156471 0.34
# 0.1 -8.058889769818062 0.34
# 1 -3.1331542785822872 0.34
# 5 -0.841086797533389 0.35
# 10 -0.4381172315908744 0.35
